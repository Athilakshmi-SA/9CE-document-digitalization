# %%
import os
import json
import xml.etree.ElementTree as ET
from detectron2.structures import BoxMode

def convert_xml_to_coco(xml_dir, image_dir, output_json):
    dataset_dicts = []

    for filename in os.listdir(xml_dir):
        if filename.endswith('.xml'):
            record = {}
            tree = ET.parse(os.path.join(xml_dir, filename))
            root = tree.getroot()

            # Get image information
            image_name = filename.replace('.xml', '.jpg')  # Assuming your images have jpg extension
            img_path = os.path.join(image_dir, image_name)
            height, width = cv2.imread(img_path).shape[:2]

            record["file_name"] = img_path
            record["image_id"] = int(filename.replace('.xml', ''))
            record["height"] = height
            record["width"] = width

            objs = []
            for obj in root.findall('object'):
                category = obj.find('name').text
                bbox = obj.find('bndbox')
                xmin = float(bbox.find('xmin').text)
                ymin = float(bbox.find('ymin').text)
                xmax = float(bbox.find('xmax').text)
                ymax = float(bbox.find('ymax').text)

                obj_dict = {
                    "bbox": [xmin, ymin, xmax, ymax],
                    "bbox_mode": BoxMode.XYXY_ABS,
                    "category_id": category
                }
                objs.append(obj_dict)

            record["annotations"] = objs
            dataset_dicts.append(record)

    with open(output_json, 'w') as json_file:
        json.dump(dataset_dicts, json_file)

xml_annotation_dir = "H:\\my dataset\\Annotations"
image_dir = "H:\\my dataset\\Images"
output_json = "instances_train.json"

convert_xml_to_coco(xml_annotation_dir, image_dir, output_json)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8816/1005325733.py in <module>
#       2 import json
#       3 import xml.etree.ElementTree as ET
# ----> 4 from detectron2.structures import BoxMode
#       5
#       6 def convert_xml_to_coco(xml_dir, image_dir, output_json):
#
# ModuleNotFoundError: No module named 'detectron2'

# %%
conda install -n myenv jupyter
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Traceback (most recent call last):
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\exceptions.py", line 1125, in __call__
#     return func(*args, **kwargs)
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\cli\main.py", line 86, in main_subshell
#     exit_code = do_call(args, p)
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\cli\conda_argparse.py", line 91, in do_call
#     module = import_module(relative_mod, __name__.rsplit('.', 1)[0])
#   File "C:\Users\asus\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1030, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\cli\main_install.py", line 8, in <module>
#     from .install import install
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\cli\install.py", line 18, in <module>
#     from ..core.index import calculate_channel_urls, get_index
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\core\index.py", line 14, in <module>
#     from .package_cache_data import PackageCacheData
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\core\package_cache_data.py", line 16, in <module>
#     from .path_actions import CacheUrlAction, ExtractPackageAction
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\core\path_actions.py", line 30, in <module>
#     from ..gateways.connection.download import download
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\gateways\connection\download.py", line 14, in <module>
#     from .session import CondaSession
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\gateways\connection\session.py", line 13, in <module>
#     from .adapters.s3 import S3Adapter
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\gateways\connection\adapters\s3.py", line 12, in <module>
#     import boto3
#   File "C:\Users\asus\anaconda3\lib\site-packages\boto3\__init__.py", line 17, in <module>
#     from boto3.session import Session
#   File "C:\Users\asus\anaconda3\lib\site-packages\boto3\session.py", line 17, in <module>
#     import botocore.session
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\session.py", line 26, in <module>
#     import botocore.client
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\client.py", line 15, in <module>
#     from botocore import waiter, xform_name
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\waiter.py", line 18, in <module>
#     from botocore.docs.docstring import WaiterDocstring
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\docs\__init__.py", line 15, in <module>
#     from botocore.docs.service import ServiceDocumenter
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\docs\service.py", line 14, in <module>
#     from botocore.docs.client import ClientDocumenter, ClientExceptionsDocumenter
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\docs\client.py", line 17, in <module>
#     from botocore.docs.example import ResponseExampleDocumenter
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\docs\example.py", line 13, in <module>
#     from botocore.docs.shape import ShapeDocumenter
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\docs\shape.py", line 19, in <module>
#     from botocore.utils import is_json_value_header
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\utils.py", line 37, in <module>
#     import botocore.httpsession
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\httpsession.py", line 45, in <module>
#     from urllib3.contrib.pyopenssl import (
#   File "C:\Users\asus\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 50, in <module>
#     import OpenSSL.crypto
#   File "C:\Users\asus\anaconda3\lib\site-packages\OpenSSL\__init__.py", line 8, in <module>
#     from OpenSSL import crypto, SSL
#   File "C:\Users\asus\anaconda3\lib\site-packages\OpenSSL\crypto.py", line 3279, in <module>
#     _lib.OpenSSL_add_all_algorithms()
# AttributeError: module 'lib' has no attribute 'OpenSSL_add_all_algorithms'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\asus\anaconda3\Scripts\conda-script.py", line 12, in <module>
#     sys.exit(main())
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\cli\main.py", line 129, in main
#     return conda_exception_handler(main, *args, **kwargs)
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\exceptions.py", line 1413, in conda_exception_handler
#     return_value = exception_handler(func, *args, **kwargs)
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\exceptions.py", line 1128, in __call__
#     return self.handle_exception(exc_val, exc_tb)
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\exceptions.py", line 1170, in handle_exception
#     return self.handle_unexpected_exception(exc_val, exc_tb)
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\exceptions.py", line 1181, in handle_unexpected_exception
#     self.print_unexpected_error_report(error_report)
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\exceptions.py", line 1251, in print_unexpected_error_report
#     from .cli.main_info import get_env_vars_str, get_main_info_str
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\cli\main_info.py", line 19, in <module>
#     from ..core.index import _supplement_index_with_system
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\core\index.py", line 14, in <module>
#     from .package_cache_data import PackageCacheData
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\core\package_cache_data.py", line 16, in <module>
#     from .path_actions import CacheUrlAction, ExtractPackageAction
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\core\path_actions.py", line 30, in <module>
#     from ..gateways.connection.download import download
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\gateways\connection\download.py", line 14, in <module>
#     from .session import CondaSession
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\gateways\connection\session.py", line 13, in <module>
#     from .adapters.s3 import S3Adapter
#   File "C:\Users\asus\anaconda3\lib\site-packages\conda\gateways\connection\adapters\s3.py", line 12, in <module>
#     import boto3
#   File "C:\Users\asus\anaconda3\lib\site-packages\boto3\__init__.py", line 17, in <module>
#     from boto3.session import Session
#   File "C:\Users\asus\anaconda3\lib\site-packages\boto3\session.py", line 17, in <module>
#     import botocore.session
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\session.py", line 26, in <module>
#     import botocore.client
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\client.py", line 15, in <module>
#     from botocore import waiter, xform_name
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\waiter.py", line 18, in <module>
#     from botocore.docs.docstring import WaiterDocstring
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\docs\__init__.py", line 15, in <module>
#     from botocore.docs.service import ServiceDocumenter
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\docs\service.py", line 14, in <module>
#     from botocore.docs.client import ClientDocumenter, ClientExceptionsDocumenter
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\docs\client.py", line 17, in <module>
#     from botocore.docs.example import ResponseExampleDocumenter
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\docs\example.py", line 13, in <module>
#     from botocore.docs.shape import ShapeDocumenter
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\docs\shape.py", line 19, in <module>
#     from botocore.utils import is_json_value_header
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\utils.py", line 37, in <module>
#     import botocore.httpsession
#   File "C:\Users\asus\anaconda3\lib\site-packages\botocore\httpsession.py", line 45, in <module>
#     from urllib3.contrib.pyopenssl import (
#   File "C:\Users\asus\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py", line 50, in <module>
#     import OpenSSL.crypto
#   File "C:\Users\asus\anaconda3\lib\site-packages\OpenSSL\__init__.py", line 8, in <module>
#     from OpenSSL import crypto, SSL
#   File "C:\Users\asus\anaconda3\lib\site-packages\OpenSSL\crypto.py", line 3279, in <module>
#     _lib.OpenSSL_add_all_algorithms()
# AttributeError: module 'lib' has no attribute 'OpenSSL_add_all_algorithms'
